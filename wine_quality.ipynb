# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('winequalityN.csv')
df.head()
df[df['type']=='red']
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4898  red            7.4             0.700         0.00             1.9
# 4899  red            7.8             0.880         0.00             2.6
# 4900  red            7.8             0.760         0.04             2.3
# 4901  red           11.2             0.280         0.56             1.9
# 4902  red            7.4             0.700         0.00             1.9
# 4903  red            7.4             0.660         0.00             1.8
# 4904  red            7.9             0.600         0.06             1.6
# 4905  red            7.3             0.650         0.00             1.2
# 4906  red            7.8             0.580         0.02             2.0
# 4907  red            7.5             0.500         0.36             6.1
# 4908  red            6.7             0.580         0.08             1.8
# 4909  red            7.5             0.500         0.36             6.1
# ...

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.describe(include='all')
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497    6487.000000       6489.000000  6494.000000     6495.000000
# unique      2            NaN               NaN          NaN             NaN
# top     white            NaN               NaN          NaN             NaN
# freq     4898            NaN               NaN          NaN             NaN
# mean      NaN       7.216579          0.339691     0.318722        5.444326
# std       NaN       1.296750          0.164649     0.145265        4.758125
# min       NaN       3.800000          0.080000     0.000000        0.600000
# 25%       NaN       6.400000          0.230000     0.250000        1.800000
# 50%       NaN       7.000000          0.290000     0.310000        3.000000
# 75%       NaN       7.700000          0.400000     0.390000        8.100000
# max       NaN      15.900000          1.580000     1.660000       65.800000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# type                    6497 non-null object
# fixed acidity           6487 non-null float64
# volatile acidity        6489 non-null float64
# citric acid             6494 non-null float64
# residual sugar          6495 non-null float64
# chlorides               6495 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6488 non-null float64
# sulphates               6493 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 659.9+ KB

# %%
missing = df.isnull().sum()
missing[missing>0]
# Out:
# fixed acidity       10
# volatile acidity     8
# citric acid          3
# residual sugar       2
# chlorides            2
# pH                   9
# sulphates            4
# dtype: int64

# %%
df_new = df.copy()
df.quality.value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
df_new['quality'] = df['quality'].apply(lambda x: 'low' if x<=5 else 'medium' if x<=7 else 'high')
df_new.quality.value_counts()
# Out:
# medium    3915
# low       2384
# high       198
# Name: quality, dtype: int64

# %% [markdown]
# lets fill the missing values

# %%
# df['fixed acidity']=df['fixed acidity'].fillna(df['fixed acidity'].mean(),inplace=True)
# df.head()
df[df['fixed acidity'].isna()]
df['fixed acidity'].dtype
# Out:
# dtype('float64')

# %%
def null_cell(df): 
    total_missing_values = df.isnull().sum() 
    missing_values_per = df.isnull().sum()/df.isnull().count() 
    null_values = pd.concat([total_missing_values, missing_values_per], axis=1, keys=['total_null', 'total_null_perc']) 
    null_values = null_values.sort_values('total_null', ascending=False) 
    return null_values[null_values['total_null'] > 0]

# %%
fill_list = (null_cell(df))
fill_list
# Out:
#                   total_null  total_null_perc
# fixed acidity             10         0.001539
# pH                         9         0.001385
# volatile acidity           8         0.001231
# sulphates                  4         0.000616
# citric acid                3         0.000462
# residual sugar             2         0.000308
# chlorides                  2         0.000308

# %%
for col in fill_list.index:
    df.loc[:, col].fillna(df.loc[:, col].mean(), inplace=True)

# %%
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
sns.boxplot(x='type',y='quality',data=df)

# %%
corr  = df.corr()
plt.figure(figsize=(15,5))
sns.heatmap(corr[corr>0.45],annot=True,)

# %% [markdown]
# while most of the corr are weak we can see free sulpher dioxide is highly correlated to total sulphur dioxide

# %%
col = ['free sulfur dioxide','total sulfur dioxide','density','residual sugar','fixed acidity','volatile acidity','quality']
sns.pairplot(data=df_new.loc[:,col],hue='quality')

# %% [markdown]
# there exist linear relationship between
# - fixed acidity and volatile acidity
# - total sulphur dioxide and free sulphur dioxide

# %%
fig = plt.figure(figsize=(22,10))

features = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']

for i in  range(len(features)):
    ax = fig.add_subplot(3,4,i+1)
    sns.boxplot(x='type',y=features[i],data=df)

# %% [markdown]
# - Red wine has high level of fixed and voltile acidity
# - Red wine has low residual sugar while high chlorides
# - Red wine has high ph and level of sulphates

# %%
fig = plt.figure(figsize=(22,10))

features = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']

for i in  range(len(features)):
    ax = fig.add_subplot(3,4,i+1)
    sns.boxplot(x='quality',y=features[i],data=df_new)

# %% [markdown]
# - low sulphate level in wines with high quality
# - high alcohol level in wines with high quality while low level in low quality
# - low density of high quality wines while low quality have higher density
# - wines with low quality have high amount of chlorides
# - high level of volatile acid in low quality wines while low level in high quality

# %% [markdown]
# ### Feature selection

# %% [markdown]
# It might be a good idea to remove one of the highly correlated between themselves non-target features, because they might be redundant.

# %%
# lets drop residual sugar and total sulphurdioxide
x = df.drop(['residual sugar','total sulfur dioxide','type'],axis=1)

y = df['type']

x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  chlorides  \
# 0            7.0              0.27         0.36      0.045
# 1            6.3              0.30         0.34      0.049
# 2            8.1              0.28         0.40      0.050
# 3            7.2              0.23         0.32      0.058
# 4            7.2              0.23         0.32      0.058
#
#    free sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                 45.0   1.0010  3.00       0.45      8.8        6
# 1                 14.0   0.9940  3.30       0.49      9.5        6
# 2                 30.0   0.9951  3.26       0.44     10.1        6
# 3                 47.0   0.9956  3.19       0.40      9.9        6
# 4                 47.0   0.9956  3.19       0.40      9.9        6

# %% [markdown]
# ### Machine learning

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

model = KNeighborsClassifier()

model.fit(x_train,y_train)

predict = model.predict(x_test)

print('Accuracy score',accuracy_score(y_test,predict))
Knn=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
print('Accuracy score after 10 fold cross validation',cross_val_score(model,x,y,cv=10,scoring='accuracy').mean())
# Out:
# Accuracy score 0.8915384615384615
# Accuracy score after 10 fold cross validation 0.8720795716106451

# %% [markdown]
# ### DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model.fit(x_train,y_train)

predict = model.predict(x_test)

print('Accuracy score',accuracy_score(y_test,predict))
DTC = cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
print('Accuracy score after 10 fold cross validation',cross_val_score(model,x,y,cv=10,scoring='accuracy').mean())
# Out:
# Accuracy score 0.9730769230769231
# Accuracy score after 10 fold cross validation 0.9584385196306101

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

model = SVC()

model.fit(x_train,y_train)

predict = model.predict(x_test)

print('Accuracy score',accuracy_score(y_test,predict))
svm = cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
print('Accuracy score after 10 fold cross validation',cross_val_score(model,x,y,cv=10,scoring='accuracy').mean())
# Out:
# Accuracy score 0.9353846153846154
# Accuracy score after 10 fold cross validation 0.9356457900751687

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(x_train,y_train)

predict = model.predict(x_test)

print('Accuracy score',accuracy_score(y_test,predict))
randomforest = cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
print('Accuracy score after 10 fold cross validation',cross_val_score(model,x,y,cv=10,scoring='accuracy').mean())
# Out:
# Accuracy score 0.9830769230769231
# Accuracy score after 10 fold cross validation 0.9816830517254245

# %%
df = pd.DataFrame({'algorithms':['KNeighborsClassifier','DecisionTreeClassifier','SVC','RandomForestClassifier'],'scores':[Knn,DTC,svm,randomforest]},)
df.head()
# Out:
#                algorithms    scores
# 0    KNeighborsClassifier  0.872080
# 1  DecisionTreeClassifier  0.960901
# 2                     SVC  0.935646
# 3  RandomForestClassifier  0.979525

# %% [markdown]
# lets predict by our randomeforest model

# %%
x_new = np.array([[7.0,0.27,0.36 ,0.045 ,45.0 ,1.0010 ,3.00 ,0.45 ,8.8 ,6],[7.4 ,0.700 ,0.00,0.076 ,11.0,0.99780 ,3.51 ,0.56 ,9.4 ,5]])

prediction = model.predict(x_new)

print(prediction)
# Out:
# ['white' 'red']
