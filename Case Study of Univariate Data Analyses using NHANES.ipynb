# %%
# %matplotlib inline
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

df = pd.read_csv('test.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.shape
# Out:
# (5735, 28)

# %%
print(df[pd.isnull(df.ALQ110)].shape)

df[pd.isnull(df.ALQ110)].head()
# Out:
# (4004, 28)
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 6       1.0       4.0  ...   112.0    74.0   76.6  165.4    28.0    38.8
# 7       2.0       4.0  ...   114.0    70.0   64.5  151.3    28.2    34.1
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df['SMQ020'].value_counts()
# Out:
# 2    3406
# 1    2319
# 9       8
# 7       2
# Name: SMQ020, dtype: int64

# %%
df['SMQ020']=df.SMQ020.replace({2:'Two',1:'One',9:'Nine',7:'Two'})
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130 SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0    One         1        62         3
# 1  83733     1.0     NaN     6.0    One         1        53         3
# 2  83734     1.0     NaN     NaN    One         1        78         3
# 3  83735     2.0     1.0     1.0    Two         2        56         3
# 4  83736     2.0     1.0     1.0    Two         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.RIAGENDR.value_counts()
# Out:
# 2    2976
# 1    2759
# Name: RIAGENDR, dtype: int64

# %%
df['RIAGENDR'] = df.RIAGENDR.replace({1:'Male',2:'Female'})
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130 SMQ020 RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0    One     Male        62         3
# 1  83733     1.0     NaN     6.0    One     Male        53         3
# 2  83734     1.0     NaN     NaN    One     Male        78         3
# 3  83735     2.0     1.0     1.0    Two   Female        56         3
# 4  83736     2.0     1.0     1.0    Two   Female        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df[pd.isna(df['ALQ101'])]
df['ALQ101'] = df.ALQ101.fillna('Missing')
df.head()
df[df['ALQ101']=='Missing'].head()
# Out:
#      SEQN   ALQ101  ALQ110  ALQ130 SMQ020 RIAGENDR  RIDAGEYR  RIDRETH1  \
# 8   83743  Missing     NaN     NaN    Two     Male        18         5
# 18  83762  Missing     NaN     NaN    One   Female        27         4
# 23  83776  Missing     NaN     NaN    Two   Female        58         1
# 28  83786  Missing     NaN     NaN    Two     Male        51         4
# 34  83799  Missing     NaN     NaN    Two   Female        37         2
#
#     DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 8        1.0       NaN  ...     NaN     NaN   72.4  166.1    26.2     NaN
# 18       1.0       4.0  ...   144.0    84.0  107.9  168.5    38.0    40.1
# 23       1.0       5.0  ...   110.0    62.0   56.6  157.5    22.8    34.5
# 28       1.0       4.0  ...   140.0    80.0  102.1  182.2    30.8    41.8
# 34       1.0       4.0  ...   110.0    72.0   66.6  161.6    25.5     NaN
#
#     BMXARML  BMXARMC  BMXWAIST  HIQ210
# 8       NaN      NaN       NaN     2.0
# ...

# %%
#numerical analysis
df.dropna().describe()
# Out:
#                SEQN  ALQ110      ALQ130    RIDAGEYR    RIDRETH1    DMDCITZN  \
# count    259.000000   259.0  259.000000  259.000000  259.000000  259.000000
# mean   88456.050193     1.0    9.138996   50.857143    3.285714    1.092664
# std     2852.402566     0.0   87.499657   16.488393    1.307191    0.290523
# min    83735.000000     1.0    1.000000   20.000000    1.000000    1.000000
# 25%    86011.000000     1.0    1.000000   38.000000    2.000000    1.000000
# 50%    88647.000000     1.0    1.000000   50.000000    3.000000    1.000000
# 75%    90427.000000     1.0    2.000000   64.000000    4.000000    1.000000
# max    93664.000000     1.0  999.000000   80.000000    5.000000    2.000000
#
#          DMDEDUC2    DMDMARTL    DMDHHSIZ       WTINT2YR  ...      BPXSY2  \
# count  259.000000  259.000000  259.000000     259.000000  ...  259.000000
# mean     3.814672    2.378378    3.123552   39957.355946  ...  124.293436
# ...

# %%
df.ALQ130.dropna().quantile(0.75)
# Out:
# 3.0

# %%
df.ALQ130.dropna().quantile(0.25)
# Out:
# 1.0

# %%
df.ALQ130.dropna().mean()
# Out:
# 3.9115122817401597

# %%
df.ALQ130.dropna().max()
# Out:
# 999.0

# %%
df.ALQ130.dropna().min()
# Out:
# 1.0

# %%
#A person is generally considered to have pre-hypertension when their systolic blood pressure is between 
#120 and 139  their diastolic blood pressure is between 80 and 89.
df[(df.BPXSY2 >=120)&(df.BPXSY2 <=139)].mean()
np.mean((df.BPXSY2 >=120)&(df.BPXSY2 <=139))
# Out:
# 0.37210113339145595

# %%
#no the basis of distolic blood pressure
np.mean((df.BPXDI1>80) & (df.BPXDI1<89))
# Out:
# 0.10357454228421971

# %%
sns.distplot(df.BMXWT.dropna(),kde=False)

# %%
sns.distplot(df.BPXSY1.dropna())

# %%
sns.distplot(df.BPXDI1.dropna())

# %%
df["agegrp"] = pd.cut(df.RIDAGEYR, [18, 30, 40, 50, 60, 70, 80]) # Create age strata based on these cut points

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='agegrp',y='BPXSY1',data=df)

# %%
#lets stratify it with gender
plt.figure(figsize=(12,5))
sns.boxplot(x='agegrp',y='BPXSY1',hue='RIAGENDR',data=df)

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='RIAGENDR',y='BPXSY1',hue='agegrp',data=df)

# %%
# for group,frame in df.groupby('agegrp'):
#     print(group,frame)
df["DMDEDUC2x"] = df.DMDEDUC2.replace({1: "<9", 2: "9-11", 3: "HS/GED", 4: "Some college/AA", 5: "College", 
                                       7: "Refused", 9: "Don't know"})
df.groupby('agegrp')['DMDEDUC2x'].value_counts()
# Out:
# agegrp    DMDEDUC2x
# (18, 30]  Some college/AA    364
#           College            278
#           HS/GED             237
#           9-11                99
#           <9                  47
# (30, 40]  Some college/AA    282
#           College            264
#           HS/GED             182
#           9-11               111
#           <9                  93
# (40, 50]  Some college/AA    262
#           College            260
#           HS/GED             171
#           9-11               112
#           <9                  98
# (50, 60]  Some college/AA    258
#           College            220
#           HS/GED             220
#           9-11               122
#           <9                 104
# (60, 70]  Some college/AA    238
#           HS/GED             192
#           College            188
#           <9                 149
#           9-11               111
# (70, 80]  Some college/AA    217
#           HS/GED             184
# ...
